# %% [markdown]
# # Practical 2: Numerical Integration of Chemical Kinetics using Python Loops
#
# ### Computer Programming Lab – Chemical Engineering
# **Topic:** Looping Constructs (`for`, `while`) with Numerical Integration of Kinetics
# **Environment:** GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: How we will use AI Copilot
#
# In this practical, GitHub Copilot is your **AI coding assistant**. Use it to understand loops, numerical integration, debugging and testing.
#
# **Do not ask Copilot to write the complete practical at the beginning.** First understand the chemical equation, convert it into a numerical calculation, and decide what must be repeated. Then use Copilot for hints, explanations and debugging.
#
# At the end, you should be able to explain your own program without depending on Copilot.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, you should be able to:
#
# 1. Understand why loops are useful for repeated chemical-engineering calculations.
# 2. Understand the basic idea of numerical integration using small time steps.
# 3. Apply the Euler method to a simple first-order reaction.
# 4. Use a `for` loop to perform a fixed number of integration steps.
# 5. Use a `while` loop when the number of steps depends on a process condition.
# 6. Calculate concentration and conversion during a reaction.
# 7. Investigate how the time step affects the numerical result.
# 8. Use GitHub Copilot to explain, debug and improve a numerical simulation.

# %% [markdown]
# ## 2. Chemical Engineering Context
#
# Chemical engineers frequently deal with equations that describe how a quantity changes with time. For example, the concentration of a reactant in a batch reactor changes as a reaction proceeds.
#
# Consider the simple first-order reaction:
#
# ```text
# A → Products
# ```
#
# For a first-order reaction, the rate of disappearance of A can be represented by:
#
# ```text
# dC/dt = -kC
# ```
#
# where:
#
# - `C` = concentration of reactant A (mol/L)
# - `t` = time (min)
# - `k` = first-order rate constant (1/min)
#
# Instead of solving the differential equation analytically, we will use **numerical integration**. This means that we calculate the concentration step-by-step over small time intervals.
#
# **Note:** This is an educational numerical model for programming practice. It is not a substitute for a rigorous reactor-design calculation.

# %% [markdown]
# ## 3. Euler Method – The Basic Idea
#
# For a small time step `Δt`, the Euler method approximates the next concentration using:
#
# ```text
# C_new = C_old + (dC/dt) × Δt
# ```
#
# Since:
#
# ```text
# dC/dt = -kC
# ```
#
# we obtain:
#
# ```text
# C_new = C_old - k × C_old × Δt
# ```
#
# The important programming idea is that this calculation is repeated many times.

# %% [markdown]
# ## 4. Example Problem
#
# A batch reactor initially contains reactant A at:
#
# - Initial concentration: `C₀ = 1.00 mol/L`
# - Rate constant: `k = 0.05 1/min`
# - Time step: `Δt = 1 min`
# - Total simulation time: `10 min`
#
# Use the Euler method to calculate the concentration at every minute.
#
# Your program should produce a sequence similar to:
#
# ```text
# Time       Concentration
# 0          1.0000
# 1          ...
# 2          ...
# ...
# 10         ...
# ```

# %% [markdown]
# ## 5. Activity 1 – Understand What Must Be Repeated
#
# Before writing Python code, identify the repeated calculation.
#
# At every time step, you need to:
#
# 1. Calculate the rate `dC/dt`.
# 2. Calculate the change in concentration.
# 3. Calculate the new concentration.
# 4. Increase the time.
#
# ### Your task
#
# Write in your own words: **Why is a loop suitable for this problem?**

# %% [markdown]
# ### Copilot Activity 1 – Understand the Loop
#
# Ask Copilot:
#
# > I am a second-year chemical engineering student learning Python. I need to repeat an Euler-method calculation for a first-order reaction at several time steps. Explain why a for loop is suitable. Do not give me the complete program.
#
# Write one or two important points you learned from Copilot.

# %%
# Activity 1
# Print the time values from 0 to 10 minutes using a for loop.
# Write your solution here.
t = 10
for i in range(t + 1):
    print(f"{i} minutes")
print("Activity 1 complete.")
# Out:
# 0 minutes
# 1 minutes
# 2 minutes
# 3 minutes
# 4 minutes
# 5 minutes
# 6 minutes
# 7 minutes
# 8 minutes
# 9 minutes
# 10 minutes
# Activity 1 complete.

# %% [markdown]
# ## 6. Activity 2 – Implement One Euler Integration Step
#
# Before creating a loop, implement **one** numerical integration step.
#
# Use:
#
# - `C = 1.00 mol/L`
# - `k = 0.05 1/min`
# - `dt = 1 min`
#
# Calculate:
#
# 1. Reaction rate `dC/dt`
# 2. New concentration `C_new`
#
# This helps you understand the calculation before repeating it.

# %% [markdown]
# ### Copilot Activity 2 – Ask for Explanation, Not the Answer
#
# Ask Copilot:
#
# > Explain how to translate dC/dt = -kC into one Euler integration step in Python. I want to understand the variables and sequence of calculations. Do not give me a complete simulation program.

# %%
# Activity 2
# Calculate one Euler step.
# Start with C = 1.00, k = 0.05 and dt = 1.
C = 1.00
k = 0.05
dt = 1
dCdt = -k * C
C_new = C + dCdt * dt
print(f"New concentration after one Euler step: {C_new:.4f}")
# Out:
# New concentration after one Euler step: 0.9500

# %% [markdown]
# ## 7. Activity 3 – Numerical Integration using a `for` Loop
#
# Now place the Euler calculation inside a `for` loop.
#
# Perform 10 integration steps.
#
# At each iteration:
#
# 1. Calculate `dC/dt`.
# 2. Update `C` using the Euler method.
# 3. Increase time by `dt`.
# 4. Display time and concentration.
#
# ### Important
#
# The concentration calculated in one step becomes the starting concentration for the next step.

# %% [markdown]
# ### Copilot Activity 3 – Debugging/Hint Prompt
#
# If you are stuck, ask:
#
# > I am implementing Euler integration for dC/dt = -kC inside a Python for loop. Explain what should be updated after each iteration and why. Do not write the complete code.

# %%
# Activity 3
# Use a for loop to numerically integrate the first-order reaction for 10 minutes.
C = 1.00
k = 0.05
dt = 1
t = 10
for t in range(t + 1):
   # print (f"{i} minutes")
    print(f"Time: {t} minutes, Concentration: {C:.4f}")
    C = C + (-k * C) * dt
# Out:
# Time: 0 minutes, Concentration: 1.0000
# Time: 1 minutes, Concentration: 0.9500
# Time: 2 minutes, Concentration: 0.9025
# Time: 3 minutes, Concentration: 0.8574
# Time: 4 minutes, Concentration: 0.8145
# Time: 5 minutes, Concentration: 0.7738
# Time: 6 minutes, Concentration: 0.7351
# Time: 7 minutes, Concentration: 0.6983
# Time: 8 minutes, Concentration: 0.6634
# Time: 9 minutes, Concentration: 0.6302
# Time: 10 minutes, Concentration: 0.5987

# %% [markdown]
# ## 8. Activity 4 – Calculate Conversion
#
# For a batch reaction, conversion can be calculated as:
#
# ```text
# Conversion (%) = ((C₀ - C) / C₀) × 100
# ```
#
# Modify your simulation so that each time step displays:
#
# - Time
# - Concentration
# - Conversion
#
# Think about whether conversion should be calculated using the **initial concentration** or the current concentration.

# %% [markdown]
# ### Copilot Activity 4 – Explain Conversion
#
# Ask Copilot:
#
# > Explain how conversion is calculated from initial and current reactant concentration in a batch reactor. Explain what happens to conversion as the reactant concentration decreases. Do not write the Python program.

# %%
# Activity 4
# Add conversion (%) to your numerical integration program.
C = 1.00
k = 0.05
dt = 1
t = 10
conversion = 0.0
for i in range(t + 1):
    print(f"Time: {i} minutes, Concentration: {C:.4f}, Conversion: {conversion:.2f}%")
    # print (f"{i} minutes")
    C = C + (-k * C) * dt
    conversion = (1 - C) * 100
print (f"Final concentration after {t} minutes: {C:.4f}")
# Out:
# Time: 0 minutes, Concentration: 1.0000, Conversion: 0.00%
# Time: 1 minutes, Concentration: 0.9500, Conversion: 5.00%
# Time: 2 minutes, Concentration: 0.9025, Conversion: 9.75%
# Time: 3 minutes, Concentration: 0.8574, Conversion: 14.26%
# Time: 4 minutes, Concentration: 0.8145, Conversion: 18.55%
# Time: 5 minutes, Concentration: 0.7738, Conversion: 22.62%
# Time: 6 minutes, Concentration: 0.7351, Conversion: 26.49%
# Time: 7 minutes, Concentration: 0.6983, Conversion: 30.17%
# Time: 8 minutes, Concentration: 0.6634, Conversion: 33.66%
# Time: 9 minutes, Concentration: 0.6302, Conversion: 36.98%
# Time: 10 minutes, Concentration: 0.5987, Conversion: 40.13%
# Final concentration after 10 minutes: 0.5688

# %% [markdown]
# ## 9. Activity 5 – Numerical Integration with a `while` Loop
#
# A `for` loop is convenient when the number of integration steps is known.
#
# Now consider a different engineering requirement:
#
# > Continue the reaction simulation until conversion reaches **80%**, but stop if the simulation time reaches **100 minutes**.
#
# The number of steps is not known in advance, so a `while` loop is appropriate.
#
# Your loop should:
#
# 1. Calculate the reaction rate.
# 2. Perform one Euler step.
# 3. Update time.
# 4. Calculate conversion.
# 5. Continue while the target has not been reached and maximum time has not been exceeded.

# %% [markdown]
# ### Copilot Activity 5 – Understand `while`
#
# Ask Copilot:
#
# > Explain how to design a while-loop condition for a chemical reaction simulation that should continue until conversion reaches 80% or time reaches 100 minutes. Explain the logic without writing the complete program.

# %%
# Activity 5
# Use a while loop for the target-conversion simulation.
t = 0
while t <= 10:
    print(f"{t} minutes")
    t += 1
print ("Activity completed.")
# Out:
# 0 minutes
# 1 minutes
# 2 minutes
# 3 minutes
# 4 minutes
# 5 minutes
# 6 minutes
# 7 minutes
# 8 minutes
# 9 minutes
# 10 minutes
# Activity completed.

# %%
C = 1.00
k = 0.05
dt = 1
t = 0
conversion = 0.0
while (conversion <=80.0 and t <= 100):
    print(f"Time: {t} minutes, Concentration: {C:.4f}, Conversion: {conversion:.2f}%")
    C = C + (-k * C) * dt
    conversion = (1 - C) * 100
    t += 1
print(f"Final concentration after {t} minutes: {C:.4f}")
# Out:
# Time: 0 minutes, Concentration: 1.0000, Conversion: 0.00%
# Time: 1 minutes, Concentration: 0.9500, Conversion: 5.00%
# Time: 2 minutes, Concentration: 0.9025, Conversion: 9.75%
# Time: 3 minutes, Concentration: 0.8574, Conversion: 14.26%
# Time: 4 minutes, Concentration: 0.8145, Conversion: 18.55%
# Time: 5 minutes, Concentration: 0.7738, Conversion: 22.62%
# Time: 6 minutes, Concentration: 0.7351, Conversion: 26.49%
# Time: 7 minutes, Concentration: 0.6983, Conversion: 30.17%
# Time: 8 minutes, Concentration: 0.6634, Conversion: 33.66%
# Time: 9 minutes, Concentration: 0.6302, Conversion: 36.98%
# Time: 10 minutes, Concentration: 0.5987, Conversion: 40.13%
# Time: 11 minutes, Concentration: 0.5688, Conversion: 43.12%
# Time: 12 minutes, Concentration: 0.5404, Conversion: 45.96%
# Time: 13 minutes, Concentration: 0.5133, Conversion: 48.67%
# Time: 14 minutes, Concentration: 0.4877, Conversion: 51.23%
# Time: 15 minutes, Concentration: 0.4633, Conversion: 53.67%
# Time: 16 minutes, Concentration: 0.4401, Conversion: 55.99%
# Time: 17 minutes, Concentration: 0.4181, Conversion: 58.19%
# Time: 18 minutes, Concentration: 0.3972, Conversion: 60.28%
# Time: 19 minutes, Concentration: 0.3774, Conversion: 62.26%
# Time: 20 minutes, Concentration: 0.3585, Conversion: 64.15%
# Time: 21 minutes, Concentration: 0.3406, Conversion: 65.94%
# Time: 22 minutes, Concentration: 0.3235, Conversion: 67.65%
# Time: 23 minutes, Concentration: 0.3074, Conversion: 69.26%
# Time: 24 minutes, Concentration: 0.2920, Conversion: 70.80%
# Time: 25 minutes, Concentration: 0.2774, Conversion: 72.26%
# Time: 26 minutes, Concentration: 0.2635, Conversion: 73.65%
# Time: 27 minutes, Concentration: 0.2503, Conversion: 74.97%
# Time: 28 minutes, Concentration: 0.2378, Conversion: 76.22%
# Time: 29 minutes, Concentration: 0.2259, Conversion: 77.41%
# Time: 30 minutes, Concentration: 0.2146, Conversion: 78.54%
# Time: 31 minutes, Concentration: 0.2039, Conversion: 79.61%
# Final concentration after 32 minutes: 0.1937

# %% [markdown]
# ## 10. Activity 6 – Investigate the Effect of Time Step
#
# The Euler method is a numerical approximation. The size of `dt` can affect the result.
#
# Run the same reaction using:
#
# - `dt = 2 min`
# - `dt = 1 min`
# - `dt = 0.5 min`
# - `dt = 0.1 min`
#
# Compare the concentration obtained at approximately 10 minutes.
#
# ### Think about it
#
# Does reducing the time step make the result change? Why might a smaller time step generally give a better numerical approximation?

# %% [markdown]
# ### Copilot Activity 6 – Understand Numerical Error
#
# Ask Copilot:
#
# > Explain in beginner-friendly terms why the time-step size can affect an Euler numerical integration result. Use a first-order chemical reaction as the example. Do not provide code.

# %%
# Activity 6
# Compare Euler integration results for different dt values.
C = 1.00
k = 0.05
dt_values = [2, 1, 0.5, 0.1]
for dt in dt_values:
    t = 0
    C = 1.00
    conversion = 0.0
    print(f"\nResults for dt = {dt}:")
    while (conversion <= 80.0 and t <= 100):
        print(f"Time: {t:.1f} minutes, Concentration: {C:.4f}, Conversion: {conversion:.2f}%")
        C = C + (-k * C) * dt
        conversion = (1 - C) * 100
        t += dt
# Out:
# Results for dt = 2:
# Time: 0.0 minutes, Concentration: 1.0000, Conversion: 0.00%
# Time: 2.0 minutes, Concentration: 0.9000, Conversion: 10.00%
# Time: 4.0 minutes, Concentration: 0.8100, Conversion: 19.00%
# Time: 6.0 minutes, Concentration: 0.7290, Conversion: 27.10%
# Time: 8.0 minutes, Concentration: 0.6561, Conversion: 34.39%
# Time: 10.0 minutes, Concentration: 0.5905, Conversion: 40.95%
# Time: 12.0 minutes, Concentration: 0.5314, Conversion: 46.86%
# Time: 14.0 minutes, Concentration: 0.4783, Conversion: 52.17%
# Time: 16.0 minutes, Concentration: 0.4305, Conversion: 56.95%
# Time: 18.0 minutes, Concentration: 0.3874, Conversion: 61.26%
# Time: 20.0 minutes, Concentration: 0.3487, Conversion: 65.13%
# Time: 22.0 minutes, Concentration: 0.3138, Conversion: 68.62%
# Time: 24.0 minutes, Concentration: 0.2824, Conversion: 71.76%
# Time: 26.0 minutes, Concentration: 0.2542, Conversion: 74.58%
# Time: 28.0 minutes, Concentration: 0.2288, Conversion: 77.12%
# Time: 30.0 minutes, Concentration: 0.2059, Conversion: 79.41%
#
# Results for dt = 1:
# Time: 0.0 minutes, Concentration: 1.0000, Conversion: 0.00%
# Time: 1.0 minutes, Concentration: 0.9500, Conversion: 5.00%
# Time: 2.0 minutes, Concentration: 0.9025, Conversion: 9.75%
# Time: 3.0 minutes, Concentration: 0.8574, Conversion: 14.26%
# Time: 4.0 minutes, Concentration: 0.8145, Conversion: 18.55%
# Time: 5.0 minutes, Concentration: 0.7738, Conversion: 22.62%
# Time: 6.0 minutes, Concentration: 0.7351, Conversion: 26.49%
# Time: 7.0 minutes, Concentration: 0.6983, Conversion: 30.17%
# Time: 8.0 minutes, Concentration: 0.6634, Conversion: 33.66%
# Time: 9.0 minutes, Concentration: 0.6302, Conversion: 36.98%
# Time: 10.0 minutes, Concentration: 0.5987, Conversion: 40.13%
# Time: 11.0 minutes, Concentration: 0.5688, Conversion: 43.12%
# Time: 12.0 minutes, Concentration: 0.5404, Conversion: 45.96%
# Time: 13.0 minutes, Concentration: 0.5133, Conversion: 48.67%
# Time: 14.0 minutes, Concentration: 0.4877, Conversion: 51.23%
# Time: 15.0 minutes, Concentration: 0.4633, Conversion: 53.67%
# Time: 16.0 minutes, Concentration: 0.4401, Conversion: 55.99%
# Time: 17.0 minutes, Concentration: 0.4181, Conversion: 58.19%
# Time: 18.0 minutes, Concentration: 0.3972, Conversion: 60.28%
# Time: 19.0 minutes, Concentration: 0.3774, Conversion: 62.26%
# Time: 20.0 minutes, Concentration: 0.3585, Conversion: 64.15%
# Time: 21.0 minutes, Concentration: 0.3406, Conversion: 65.94%
# Time: 22.0 minutes, Concentration: 0.3235, Conversion: 67.65%
# Time: 23.0 minutes, Concentration: 0.3074, Conversion: 69.26%
# Time: 24.0 minutes, Concentration: 0.2920, Conversion: 70.80%
# Time: 25.0 minutes, Concentration: 0.2774, Conversion: 72.26%
# Time: 26.0 minutes, Concentration: 0.2635, Conversion: 73.65%
# Time: 27.0 minutes, Concentration: 0.2503, Conversion: 74.97%
# Time: 28.0 minutes, Concentration: 0.2378, Conversion: 76.22%
# Time: 29.0 minutes, Concentration: 0.2259, Conversion: 77.41%
# Time: 30.0 minutes, Concentration: 0.2146, Conversion: 78.54%
# Time: 31.0 minutes, Concentration: 0.2039, Conversion: 79.61%
#
# Results for dt = 0.5:
# Time: 0.0 minutes, Concentration: 1.0000, Conversion: 0.00%
# Time: 0.5 minutes, Concentration: 0.9750, Conversion: 2.50%
# Time: 1.0 minutes, Concentration: 0.9506, Conversion: 4.94%
# Time: 1.5 minutes, Concentration: 0.9269, Conversion: 7.31%
# Time: 2.0 minutes, Concentration: 0.9037, Conversion: 9.63%
# Time: 2.5 minutes, Concentration: 0.8811, Conversion: 11.89%
# Time: 3.0 minutes, Concentration: 0.8591, Conversion: 14.09%
# Time: 3.5 minutes, Concentration: 0.8376, Conversion: 16.24%
# Time: 4.0 minutes, Concentration: 0.8167, Conversion: 18.33%
# Time: 4.5 minutes, Concentration: 0.7962, Conversion: 20.38%
# Time: 5.0 minutes, Concentration: 0.7763, Conversion: 22.37%
# Time: 5.5 minutes, Concentration: 0.7569, Conversion: 24.31%
# Time: 6.0 minutes, Concentration: 0.7380, Conversion: 26.20%
# Time: 6.5 minutes, Concentration: 0.7195, Conversion: 28.05%
# Time: 7.0 minutes, Concentration: 0.7016, Conversion: 29.84%
# Time: 7.5 minutes, Concentration: 0.6840, Conversion: 31.60%
# Time: 8.0 minutes, Concentration: 0.6669, Conversion: 33.31%
# Time: 8.5 minutes, Concentration: 0.6502, Conversion: 34.98%
# Time: 9.0 minutes, Concentration: 0.6340, Conversion: 36.60%
# Time: 9.5 minutes, Concentration: 0.6181, Conversion: 38.19%
# Time: 10.0 minutes, Concentration: 0.6027, Conversion: 39.73%
# Time: 10.5 minutes, Concentration: 0.5876, Conversion: 41.24%
# Time: 11.0 minutes, Concentration: 0.5729, Conversion: 42.71%
# Time: 11.5 minutes, Concentration: 0.5586, Conversion: 44.14%
# Time: 12.0 minutes, Concentration: 0.5446, Conversion: 45.54%
# Time: 12.5 minutes, Concentration: 0.5310, Conversion: 46.90%
# Time: 13.0 minutes, Concentration: 0.5177, Conversion: 48.23%
# Time: 13.5 minutes, Concentration: 0.5048, Conversion: 49.52%
# Time: 14.0 minutes, Concentration: 0.4922, Conversion: 50.78%
# Time: 14.5 minutes, Concentration: 0.4799, Conversion: 52.01%
# Time: 15.0 minutes, Concentration: 0.4679, Conversion: 53.21%
# Time: 15.5 minutes, Concentration: 0.4562, Conversion: 54.38%
# Time: 16.0 minutes, Concentration: 0.4448, Conversion: 55.52%
# Time: 16.5 minutes, Concentration: 0.4337, Conversion: 56.63%
# Time: 17.0 minutes, Concentration: 0.4228, Conversion: 57.72%
# Time: 17.5 minutes, Concentration: 0.4123, Conversion: 58.77%
# Time: 18.0 minutes, Concentration: 0.4019, Conversion: 59.81%
# Time: 18.5 minutes, Concentration: 0.3919, Conversion: 60.81%
# Time: 19.0 minutes, Concentration: 0.3821, Conversion: 61.79%
# Time: 19.5 minutes, Concentration: 0.3725, Conversion: 62.75%
# Time: 20.0 minutes, Concentration: 0.3632, Conversion: 63.68%
# Time: 20.5 minutes, Concentration: 0.3542, Conversion: 64.58%
# Time: 21.0 minutes, Concentration: 0.3453, Conversion: 65.47%
# Time: 21.5 minutes, Concentration: 0.3367, Conversion: 66.33%
# Time: 22.0 minutes, Concentration: 0.3282, Conversion: 67.18%
# Time: 22.5 minutes, Concentration: 0.3200, Conversion: 68.00%
# Time: 23.0 minutes, Concentration: 0.3120, Conversion: 68.80%
# Time: 23.5 minutes, Concentration: 0.3042, Conversion: 69.58%
# Time: 24.0 minutes, Concentration: 0.2966, Conversion: 70.34%
# Time: 24.5 minutes, Concentration: 0.2892, Conversion: 71.08%
# Time: 25.0 minutes, Concentration: 0.2820, Conversion: 71.80%
# Time: 25.5 minutes, Concentration: 0.2749, Conversion: 72.51%
# Time: 26.0 minutes, Concentration: 0.2681, Conversion: 73.19%
# Time: 26.5 minutes, Concentration: 0.2614, Conversion: 73.86%
# Time: 27.0 minutes, Concentration: 0.2548, Conversion: 74.52%
# Time: 27.5 minutes, Concentration: 0.2485, Conversion: 75.15%
# Time: 28.0 minutes, Concentration: 0.2422, Conversion: 75.78%
# Time: 28.5 minutes, Concentration: 0.2362, Conversion: 76.38%
# Time: 29.0 minutes, Concentration: 0.2303, Conversion: 76.97%
# Time: 29.5 minutes, Concentration: 0.2245, Conversion: 77.55%
# Time: 30.0 minutes, Concentration: 0.2189, Conversion: 78.11%
# Time: 30.5 minutes, Concentration: 0.2134, Conversion: 78.66%
# Time: 31.0 minutes, Concentration: 0.2081, Conversion: 79.19%
# Time: 31.5 minutes, Concentration: 0.2029, Conversion: 79.71%
#
# Results for dt = 0.1:
# Time: 0.0 minutes, Concentration: 1.0000, Conversion: 0.00%
# Time: 0.1 minutes, Concentration: 0.9950, Conversion: 0.50%
# Time: 0.2 minutes, Concentration: 0.9900, Conversion: 1.00%
# Time: 0.3 minutes, Concentration: 0.9851, Conversion: 1.49%
# Time: 0.4 minutes, Concentration: 0.9801, Conversion: 1.99%
# Time: 0.5 minutes, Concentration: 0.9752, Conversion: 2.48%
# Time: 0.6 minutes, Concentration: 0.9704, Conversion: 2.96%
# Time: 0.7 minutes, Concentration: 0.9655, Conversion: 3.45%
# Time: 0.8 minutes, Concentration: 0.9607, Conversion: 3.93%
# Time: 0.9 minutes, Concentration: 0.9559, Conversion: 4.41%
# Time: 1.0 minutes, Concentration: 0.9511, Conversion: 4.89%
# Time: 1.1 minutes, Concentration: 0.9464, Conversion: 5.36%
# Time: 1.2 minutes, Concentration: 0.9416, Conversion: 5.84%
# Time: 1.3 minutes, Concentration: 0.9369, Conversion: 6.31%
# Time: 1.4 minutes, Concentration: 0.9322, Conversion: 6.78%
# Time: 1.5 minutes, Concentration: 0.9276, Conversion: 7.24%
# Time: 1.6 minutes, Concentration: 0.9229, Conversion: 7.71%
# Time: 1.7 minutes, Concentration: 0.9183, Conversion: 8.17%
# Time: 1.8 minutes, Concentration: 0.9137, Conversion: 8.63%
# Time: 1.9 minutes, Concentration: 0.9092, Conversion: 9.08%
# Time: 2.0 minutes, Concentration: 0.9046, Conversion: 9.54%
# Time: 2.1 minutes, Concentration: 0.9001, Conversion: 9.99%
# Time: 2.2 minutes, Concentration: 0.8956, Conversion: 10.44%
# Time: 2.3 minutes, Concentration: 0.8911, Conversion: 10.89%
# Time: 2.4 minutes, Concentration: 0.8867, Conversion: 11.33%
# Time: 2.5 minutes, Concentration: 0.8822, Conversion: 11.78%
# Time: 2.6 minutes, Concentration: 0.8778, Conversion: 12.22%
# Time: 2.7 minutes, Concentration: 0.8734, Conversion: 12.66%
# Time: 2.8 minutes, Concentration: 0.8691, Conversion: 13.09%
# Time: 2.9 minutes, Concentration: 0.8647, Conversion: 13.53%
# Time: 3.0 minutes, Concentration: 0.8604, Conversion: 13.96%
# Time: 3.1 minutes, Concentration: 0.8561, Conversion: 14.39%
# Time: 3.2 minutes, Concentration: 0.8518, Conversion: 14.82%
# Time: 3.3 minutes, Concentration: 0.8475, Conversion: 15.25%
# Time: 3.4 minutes, Concentration: 0.8433, Conversion: 15.67%
# Time: 3.5 minutes, Concentration: 0.8391, Conversion: 16.09%
# Time: 3.6 minutes, Concentration: 0.8349, Conversion: 16.51%
# Time: 3.7 minutes, Concentration: 0.8307, Conversion: 16.93%
# Time: 3.8 minutes, Concentration: 0.8266, Conversion: 17.34%
# Time: 3.9 minutes, Concentration: 0.8224, Conversion: 17.76%
# Time: 4.0 minutes, Concentration: 0.8183, Conversion: 18.17%
# Time: 4.1 minutes, Concentration: 0.8142, Conversion: 18.58%
# Time: 4.2 minutes, Concentration: 0.8102, Conversion: 18.98%
# Time: 4.3 minutes, Concentration: 0.8061, Conversion: 19.39%
# Time: 4.4 minutes, Concentration: 0.8021, Conversion: 19.79%
# Time: 4.5 minutes, Concentration: 0.7981, Conversion: 20.19%
# Time: 4.6 minutes, Concentration: 0.7941, Conversion: 20.59%
# Time: 4.7 minutes, Concentration: 0.7901, Conversion: 20.99%
# Time: 4.8 minutes, Concentration: 0.7862, Conversion: 21.38%
# Time: 4.9 minutes, Concentration: 0.7822, Conversion: 21.78%
# Time: 5.0 minutes, Concentration: 0.7783, Conversion: 22.17%
# Time: 5.1 minutes, Concentration: 0.7744, Conversion: 22.56%
# Time: 5.2 minutes, Concentration: 0.7705, Conversion: 22.95%
# Time: 5.3 minutes, Concentration: 0.7667, Conversion: 23.33%
# Time: 5.4 minutes, Concentration: 0.7629, Conversion: 23.71%
# Time: 5.5 minutes, Concentration: 0.7590, Conversion: 24.10%
# Time: 5.6 minutes, Concentration: 0.7553, Conversion: 24.47%
# Time: 5.7 minutes, Concentration: 0.7515, Conversion: 24.85%
# Time: 5.8 minutes, Concentration: 0.7477, Conversion: 25.23%
# Time: 5.9 minutes, Concentration: 0.7440, Conversion: 25.60%
# Time: 6.0 minutes, Concentration: 0.7403, Conversion: 25.97%
# Time: 6.1 minutes, Concentration: 0.7366, Conversion: 26.34%
# Time: 6.2 minutes, Concentration: 0.7329, Conversion: 26.71%
# Time: 6.3 minutes, Concentration: 0.7292, Conversion: 27.08%
# Time: 6.4 minutes, Concentration: 0.7256, Conversion: 27.44%
# Time: 6.5 minutes, Concentration: 0.7219, Conversion: 27.81%
# Time: 6.6 minutes, Concentration: 0.7183, Conversion: 28.17%
# Time: 6.7 minutes, Concentration: 0.7147, Conversion: 28.53%
# Time: 6.8 minutes, Concentration: 0.7112, Conversion: 28.88%
# Time: 6.9 minutes, Concentration: 0.7076, Conversion: 29.24%
# Time: 7.0 minutes, Concentration: 0.7041, Conversion: 29.59%
# Time: 7.1 minutes, Concentration: 0.7005, Conversion: 29.95%
# Time: 7.2 minutes, Concentration: 0.6970, Conversion: 30.30%
# Time: 7.3 minutes, Concentration: 0.6936, Conversion: 30.64%
# Time: 7.4 minutes, Concentration: 0.6901, Conversion: 30.99%
# Time: 7.5 minutes, Concentration: 0.6866, Conversion: 31.34%
# Time: 7.6 minutes, Concentration: 0.6832, Conversion: 31.68%
# Time: 7.7 minutes, Concentration: 0.6798, Conversion: 32.02%
# Time: 7.8 minutes, Concentration: 0.6764, Conversion: 32.36%
# Time: 7.9 minutes, Concentration: 0.6730, Conversion: 32.70%
# Time: 8.0 minutes, Concentration: 0.6696, Conversion: 33.04%
# Time: 8.1 minutes, Concentration: 0.6663, Conversion: 33.37%
# Time: 8.2 minutes, Concentration: 0.6630, Conversion: 33.70%
# Time: 8.3 minutes, Concentration: 0.6597, Conversion: 34.03%
# Time: 8.4 minutes, Concentration: 0.6564, Conversion: 34.36%
# Time: 8.5 minutes, Concentration: 0.6531, Conversion: 34.69%
# Time: 8.6 minutes, Concentration: 0.6498, Conversion: 35.02%
# Time: 8.7 minutes, Concentration: 0.6466, Conversion: 35.34%
# Time: 8.8 minutes, Concentration: 0.6433, Conversion: 35.67%
# Time: 8.9 minutes, Concentration: 0.6401, Conversion: 35.99%
# Time: 9.0 minutes, Concentration: 0.6369, Conversion: 36.31%
# Time: 9.1 minutes, Concentration: 0.6337, Conversion: 36.63%
# Time: 9.2 minutes, Concentration: 0.6306, Conversion: 36.94%
# Time: 9.3 minutes, Concentration: 0.6274, Conversion: 37.26%
# Time: 9.4 minutes, Concentration: 0.6243, Conversion: 37.57%
# Time: 9.5 minutes, Concentration: 0.6211, Conversion: 37.89%
# Time: 9.6 minutes, Concentration: 0.6180, Conversion: 38.20%
# Time: 9.7 minutes, Concentration: 0.6149, Conversion: 38.51%
# Time: 9.8 minutes, Concentration: 0.6119, Conversion: 38.81%
# Time: 9.9 minutes, Concentration: 0.6088, Conversion: 39.12%
# Time: 10.0 minutes, Concentration: 0.6058, Conversion: 39.42%
# Time: 10.1 minutes, Concentration: 0.6027, Conversion: 39.73%
# Time: 10.2 minutes, Concentration: 0.5997, Conversion: 40.03%
# Time: 10.3 minutes, Concentration: 0.5967, Conversion: 40.33%
# Time: 10.4 minutes, Concentration: 0.5937, Conversion: 40.63%
# Time: 10.5 minutes, Concentration: 0.5908, Conversion: 40.92%
# Time: 10.6 minutes, Concentration: 0.5878, Conversion: 41.22%
# Time: 10.7 minutes, Concentration: 0.5849, Conversion: 41.51%
# Time: 10.8 minutes, Concentration: 0.5820, Conversion: 41.80%
# Time: 10.9 minutes, Concentration: 0.5790, Conversion: 42.10%
# Time: 11.0 minutes, Concentration: 0.5762, Conversion: 42.38%
# Time: 11.1 minutes, Concentration: 0.5733, Conversion: 42.67%
# Time: 11.2 minutes, Concentration: 0.5704, Conversion: 42.96%
# Time: 11.3 minutes, Concentration: 0.5676, Conversion: 43.24%
# Time: 11.4 minutes, Concentration: 0.5647, Conversion: 43.53%
# Time: 11.5 minutes, Concentration: 0.5619, Conversion: 43.81%
# Time: 11.6 minutes, Concentration: 0.5591, Conversion: 44.09%
# Time: 11.7 minutes, Concentration: 0.5563, Conversion: 44.37%
# Time: 11.8 minutes, Concentration: 0.5535, Conversion: 44.65%
# Time: 11.9 minutes, Concentration: 0.5507, Conversion: 44.93%
# Time: 12.0 minutes, Concentration: 0.5480, Conversion: 45.20%
# Time: 12.1 minutes, Concentration: 0.5452, Conversion: 45.48%
# Time: 12.2 minutes, Concentration: 0.5425, Conversion: 45.75%
# Time: 12.3 minutes, Concentration: 0.5398, Conversion: 46.02%
# Time: 12.4 minutes, Concentration: 0.5371, Conversion: 46.29%
# Time: 12.5 minutes, Concentration: 0.5344, Conversion: 46.56%
# Time: 12.6 minutes, Concentration: 0.5318, Conversion: 46.82%
# Time: 12.7 minutes, Concentration: 0.5291, Conversion: 47.09%
# Time: 12.8 minutes, Concentration: 0.5264, Conversion: 47.36%
# Time: 12.9 minutes, Concentration: 0.5238, Conversion: 47.62%
# Time: 13.0 minutes, Concentration: 0.5212, Conversion: 47.88%
# Time: 13.1 minutes, Concentration: 0.5186, Conversion: 48.14%
# Time: 13.2 minutes, Concentration: 0.5160, Conversion: 48.40%
# Time: 13.3 minutes, Concentration: 0.5134, Conversion: 48.66%
# Time: 13.4 minutes, Concentration: 0.5108, Conversion: 48.92%
# Time: 13.5 minutes, Concentration: 0.5083, Conversion: 49.17%
# Time: 13.6 minutes, Concentration: 0.5058, Conversion: 49.42%
# Time: 13.7 minutes, Concentration: 0.5032, Conversion: 49.68%
# Time: 13.8 minutes, Concentration: 0.5007, Conversion: 49.93%
# Time: 13.9 minutes, Concentration: 0.4982, Conversion: 50.18%
# Time: 14.0 minutes, Concentration: 0.4957, Conversion: 50.43%
# Time: 14.1 minutes, Concentration: 0.4932, Conversion: 50.68%
# Time: 14.2 minutes, Concentration: 0.4908, Conversion: 50.92%
# Time: 14.3 minutes, Concentration: 0.4883, Conversion: 51.17%
# Time: 14.4 minutes, Concentration: 0.4859, Conversion: 51.41%
# Time: 14.5 minutes, Concentration: 0.4834, Conversion: 51.66%
# Time: 14.6 minutes, Concentration: 0.4810, Conversion: 51.90%
# Time: 14.7 minutes, Concentration: 0.4786, Conversion: 52.14%
# Time: 14.8 minutes, Concentration: 0.4762, Conversion: 52.38%
# Time: 14.9 minutes, Concentration: 0.4738, Conversion: 52.62%
# Time: 15.0 minutes, Concentration: 0.4715, Conversion: 52.85%
# Time: 15.1 minutes, Concentration: 0.4691, Conversion: 53.09%
# Time: 15.2 minutes, Concentration: 0.4668, Conversion: 53.32%
# Time: 15.3 minutes, Concentration: 0.4644, Conversion: 53.56%
# Time: 15.4 minutes, Concentration: 0.4621, Conversion: 53.79%
# Time: 15.5 minutes, Concentration: 0.4598, Conversion: 54.02%
# Time: 15.6 minutes, Concentration: 0.4575, Conversion: 54.25%
# Time: 15.7 minutes, Concentration: 0.4552, Conversion: 54.48%
# Time: 15.8 minutes, Concentration: 0.4529, Conversion: 54.71%
# Time: 15.9 minutes, Concentration: 0.4507, Conversion: 54.93%
# Time: 16.0 minutes, Concentration: 0.4484, Conversion: 55.16%
# Time: 16.1 minutes, Concentration: 0.4462, Conversion: 55.38%
# Time: 16.2 minutes, Concentration: 0.4440, Conversion: 55.60%
# Time: 16.3 minutes, Concentration: 0.4417, Conversion: 55.83%
# Time: 16.4 minutes, Concentration: 0.4395, Conversion: 56.05%
# Time: 16.5 minutes, Concentration: 0.4373, Conversion: 56.27%
# Time: 16.6 minutes, Concentration: 0.4351, Conversion: 56.49%
# Time: 16.7 minutes, Concentration: 0.4330, Conversion: 56.70%
# Time: 16.8 minutes, Concentration: 0.4308, Conversion: 56.92%
# Time: 16.9 minutes, Concentration: 0.4286, Conversion: 57.14%
# Time: 17.0 minutes, Concentration: 0.4265, Conversion: 57.35%
# Time: 17.1 minutes, Concentration: 0.4244, Conversion: 57.56%
# Time: 17.2 minutes, Concentration: 0.4223, Conversion: 57.77%
# Time: 17.3 minutes, Concentration: 0.4201, Conversion: 57.99%
# Time: 17.4 minutes, Concentration: 0.4180, Conversion: 58.20%
# Time: 17.5 minutes, Concentration: 0.4159, Conversion: 58.41%
# Time: 17.6 minutes, Concentration: 0.4139, Conversion: 58.61%
# Time: 17.7 minutes, Concentration: 0.4118, Conversion: 58.82%
# Time: 17.8 minutes, Concentration: 0.4097, Conversion: 59.03%
# Time: 17.9 minutes, Concentration: 0.4077, Conversion: 59.23%
# Time: 18.0 minutes, Concentration: 0.4057, Conversion: 59.43%
# Time: 18.1 minutes, Concentration: 0.4036, Conversion: 59.64%
# Time: 18.2 minutes, Concentration: 0.4016, Conversion: 59.84%
# Time: 18.3 minutes, Concentration: 0.3996, Conversion: 60.04%
# Time: 18.4 minutes, Concentration: 0.3976, Conversion: 60.24%
# Time: 18.5 minutes, Concentration: 0.3956, Conversion: 60.44%
# Time: 18.6 minutes, Concentration: 0.3936, Conversion: 60.64%
# Time: 18.7 minutes, Concentration: 0.3917, Conversion: 60.83%
# Time: 18.8 minutes, Concentration: 0.3897, Conversion: 61.03%
# Time: 18.9 minutes, Concentration: 0.3878, Conversion: 61.22%
# Time: 19.0 minutes, Concentration: 0.3858, Conversion: 61.42%
# Time: 19.1 minutes, Concentration: 0.3839, Conversion: 61.61%
# Time: 19.2 minutes, Concentration: 0.3820, Conversion: 61.80%
# Time: 19.3 minutes, Concentration: 0.3801, Conversion: 61.99%
# Time: 19.4 minutes, Concentration: 0.3782, Conversion: 62.18%
# Time: 19.5 minutes, Concentration: 0.3763, Conversion: 62.37%
# Time: 19.6 minutes, Concentration: 0.3744, Conversion: 62.56%
# Time: 19.7 minutes, Concentration: 0.3725, Conversion: 62.75%
# Time: 19.8 minutes, Concentration: 0.3707, Conversion: 62.93%
# Time: 19.9 minutes, Concentration: 0.3688, Conversion: 63.12%
# Time: 20.0 minutes, Concentration: 0.3670, Conversion: 63.30%
# Time: 20.1 minutes, Concentration: 0.3651, Conversion: 63.49%
# Time: 20.2 minutes, Concentration: 0.3633, Conversion: 63.67%
# Time: 20.3 minutes, Concentration: 0.3615, Conversion: 63.85%
# Time: 20.4 minutes, Concentration: 0.3597, Conversion: 64.03%
# Time: 20.5 minutes, Concentration: 0.3579, Conversion: 64.21%
# Time: 20.6 minutes, Concentration: 0.3561, Conversion: 64.39%
# Time: 20.7 minutes, Concentration: 0.3543, Conversion: 64.57%
# Time: 20.8 minutes, Concentration: 0.3525, Conversion: 64.75%
# Time: 20.9 minutes, Concentration: 0.3508, Conversion: 64.92%
# Time: 21.0 minutes, Concentration: 0.3490, Conversion: 65.10%
# Time: 21.1 minutes, Concentration: 0.3473, Conversion: 65.27%
# Time: 21.2 minutes, Concentration: 0.3455, Conversion: 65.45%
# Time: 21.3 minutes, Concentration: 0.3438, Conversion: 65.62%
# Time: 21.4 minutes, Concentration: 0.3421, Conversion: 65.79%
# Time: 21.5 minutes, Concentration: 0.3404, Conversion: 65.96%
# Time: 21.6 minutes, Concentration: 0.3387, Conversion: 66.13%
# Time: 21.7 minutes, Concentration: 0.3370, Conversion: 66.30%
# Time: 21.8 minutes, Concentration: 0.3353, Conversion: 66.47%
# Time: 21.9 minutes, Concentration: 0.3336, Conversion: 66.64%
# Time: 22.0 minutes, Concentration: 0.3320, Conversion: 66.80%
# Time: 22.1 minutes, Concentration: 0.3303, Conversion: 66.97%
# Time: 22.2 minutes, Concentration: 0.3286, Conversion: 67.14%
# Time: 22.3 minutes, Concentration: 0.3270, Conversion: 67.30%
# Time: 22.4 minutes, Concentration: 0.3254, Conversion: 67.46%
# Time: 22.5 minutes, Concentration: 0.3237, Conversion: 67.63%
# Time: 22.6 minutes, Concentration: 0.3221, Conversion: 67.79%
# Time: 22.7 minutes, Concentration: 0.3205, Conversion: 67.95%
# Time: 22.8 minutes, Concentration: 0.3189, Conversion: 68.11%
# Time: 22.9 minutes, Concentration: 0.3173, Conversion: 68.27%
# Time: 23.0 minutes, Concentration: 0.3157, Conversion: 68.43%
# Time: 23.1 minutes, Concentration: 0.3141, Conversion: 68.59%
# Time: 23.2 minutes, Concentration: 0.3126, Conversion: 68.74%
# Time: 23.3 minutes, Concentration: 0.3110, Conversion: 68.90%
# Time: 23.4 minutes, Concentration: 0.3095, Conversion: 69.05%
# Time: 23.5 minutes, Concentration: 0.3079, Conversion: 69.21%
# Time: 23.6 minutes, Concentration: 0.3064, Conversion: 69.36%
# Time: 23.7 minutes, Concentration: 0.3048, Conversion: 69.52%
# Time: 23.8 minutes, Concentration: 0.3033, Conversion: 69.67%
# Time: 23.9 minutes, Concentration: 0.3018, Conversion: 69.82%
# Time: 24.0 minutes, Concentration: 0.3003, Conversion: 69.97%
# Time: 24.1 minutes, Concentration: 0.2988, Conversion: 70.12%
# Time: 24.2 minutes, Concentration: 0.2973, Conversion: 70.27%
# Time: 24.3 minutes, Concentration: 0.2958, Conversion: 70.42%
# Time: 24.4 minutes, Concentration: 0.2943, Conversion: 70.57%
# Time: 24.5 minutes, Concentration: 0.2929, Conversion: 70.71%
# Time: 24.6 minutes, Concentration: 0.2914, Conversion: 70.86%
# Time: 24.7 minutes, Concentration: 0.2899, Conversion: 71.01%
# Time: 24.8 minutes, Concentration: 0.2885, Conversion: 71.15%
# Time: 24.9 minutes, Concentration: 0.2870, Conversion: 71.30%
# Time: 25.0 minutes, Concentration: 0.2856, Conversion: 71.44%
# Time: 25.1 minutes, Concentration: 0.2842, Conversion: 71.58%
# Time: 25.2 minutes, Concentration: 0.2828, Conversion: 71.72%
# Time: 25.3 minutes, Concentration: 0.2813, Conversion: 71.87%
# Time: 25.4 minutes, Concentration: 0.2799, Conversion: 72.01%
# Time: 25.5 minutes, Concentration: 0.2785, Conversion: 72.15%
# Time: 25.6 minutes, Concentration: 0.2771, Conversion: 72.29%
# Time: 25.7 minutes, Concentration: 0.2758, Conversion: 72.42%
# Time: 25.8 minutes, Concentration: 0.2744, Conversion: 72.56%
# Time: 25.9 minutes, Concentration: 0.2730, Conversion: 72.70%
# Time: 26.0 minutes, Concentration: 0.2716, Conversion: 72.84%
# Time: 26.1 minutes, Concentration: 0.2703, Conversion: 72.97%
# Time: 26.2 minutes, Concentration: 0.2689, Conversion: 73.11%
# Time: 26.3 minutes, Concentration: 0.2676, Conversion: 73.24%
# Time: 26.4 minutes, Concentration: 0.2663, Conversion: 73.37%
# Time: 26.5 minutes, Concentration: 0.2649, Conversion: 73.51%
# Time: 26.6 minutes, Concentration: 0.2636, Conversion: 73.64%
# Time: 26.7 minutes, Concentration: 0.2623, Conversion: 73.77%
# Time: 26.8 minutes, Concentration: 0.2610, Conversion: 73.90%
# Time: 26.9 minutes, Concentration: 0.2597, Conversion: 74.03%
# Time: 27.0 minutes, Concentration: 0.2584, Conversion: 74.16%
# Time: 27.1 minutes, Concentration: 0.2571, Conversion: 74.29%
# Time: 27.2 minutes, Concentration: 0.2558, Conversion: 74.42%
# Time: 27.3 minutes, Concentration: 0.2545, Conversion: 74.55%
# Time: 27.4 minutes, Concentration: 0.2532, Conversion: 74.68%
# Time: 27.5 minutes, Concentration: 0.2520, Conversion: 74.80%
# Time: 27.6 minutes, Concentration: 0.2507, Conversion: 74.93%
# Time: 27.7 minutes, Concentration: 0.2495, Conversion: 75.05%
# Time: 27.8 minutes, Concentration: 0.2482, Conversion: 75.18%
# Time: 27.9 minutes, Concentration: 0.2470, Conversion: 75.30%
# Time: 28.0 minutes, Concentration: 0.2457, Conversion: 75.43%
# Time: 28.1 minutes, Concentration: 0.2445, Conversion: 75.55%
# Time: 28.2 minutes, Concentration: 0.2433, Conversion: 75.67%
# Time: 28.3 minutes, Concentration: 0.2421, Conversion: 75.79%
# Time: 28.4 minutes, Concentration: 0.2409, Conversion: 75.91%
# Time: 28.5 minutes, Concentration: 0.2397, Conversion: 76.03%
# Time: 28.6 minutes, Concentration: 0.2385, Conversion: 76.15%
# Time: 28.7 minutes, Concentration: 0.2373, Conversion: 76.27%
# Time: 28.8 minutes, Concentration: 0.2361, Conversion: 76.39%
# Time: 28.9 minutes, Concentration: 0.2349, Conversion: 76.51%
# Time: 29.0 minutes, Concentration: 0.2337, Conversion: 76.63%
# Time: 29.1 minutes, Concentration: 0.2326, Conversion: 76.74%
# Time: 29.2 minutes, Concentration: 0.2314, Conversion: 76.86%
# Time: 29.3 minutes, Concentration: 0.2302, Conversion: 76.98%
# Time: 29.4 minutes, Concentration: 0.2291, Conversion: 77.09%
# Time: 29.5 minutes, Concentration: 0.2279, Conversion: 77.21%
# Time: 29.6 minutes, Concentration: 0.2268, Conversion: 77.32%
# Time: 29.7 minutes, Concentration: 0.2257, Conversion: 77.43%
# Time: 29.8 minutes, Concentration: 0.2245, Conversion: 77.55%
# Time: 29.9 minutes, Concentration: 0.2234, Conversion: 77.66%
# Time: 30.0 minutes, Concentration: 0.2223, Conversion: 77.77%
# Time: 30.1 minutes, Concentration: 0.2212, Conversion: 77.88%
# Time: 30.2 minutes, Concentration: 0.2201, Conversion: 77.99%
# Time: 30.3 minutes, Concentration: 0.2190, Conversion: 78.10%
# Time: 30.4 minutes, Concentration: 0.2179, Conversion: 78.21%
# Time: 30.5 minutes, Concentration: 0.2168, Conversion: 78.32%
# Time: 30.6 minutes, Concentration: 0.2157, Conversion: 78.43%
# Time: 30.7 minutes, Concentration: 0.2146, Conversion: 78.54%
# Time: 30.8 minutes, Concentration: 0.2136, Conversion: 78.64%
# Time: 30.9 minutes, Concentration: 0.2125, Conversion: 78.75%
# Time: 31.0 minutes, Concentration: 0.2114, Conversion: 78.86%
# Time: 31.1 minutes, Concentration: 0.2104, Conversion: 78.96%
# Time: 31.2 minutes, Concentration: 0.2093, Conversion: 79.07%
# Time: 31.3 minutes, Concentration: 0.2083, Conversion: 79.17%
# Time: 31.4 minutes, Concentration: 0.2072, Conversion: 79.28%
# Time: 31.5 minutes, Concentration: 0.2062, Conversion: 79.38%
# Time: 31.6 minutes, Concentration: 0.2052, Conversion: 79.48%
# Time: 31.7 minutes, Concentration: 0.2041, Conversion: 79.59%
# Time: 31.8 minutes, Concentration: 0.2031, Conversion: 79.69%
# Time: 31.9 minutes, Concentration: 0.2021, Conversion: 79.79%
# Time: 32.0 minutes, Concentration: 0.2011, Conversion: 79.89%
# Time: 32.1 minutes, Concentration: 0.2001, Conversion: 79.99%

# %% [markdown]
# ## 11. Activity 7 – Compare with the Analytical Solution
#
# For a first-order reaction, the analytical solution is:
#
# ```text
# C(t) = C₀ exp(-kt)
# ```
#
# Use Python's `math.exp()` to calculate the analytical concentration at selected times.
#
# Then compare it with your Euler result.
#
# Calculate the absolute error:
#
# ```text
# Absolute Error = |Euler concentration - Analytical concentration|
# ```
#
# This activity helps you understand that numerical integration is an **approximation**.

# %% [markdown]
# ### Copilot Activity 7 – Comparison and Explanation
#
# Ask Copilot:
#
# > Explain the difference between a numerical Euler solution and the analytical solution of a first-order reaction. Why can their values be different? Do not write the complete comparison program.

# %%
# Activity 7
# Compare Euler and analytical concentrations at selected times.
# Out:
#   Cell In[4], line 7
#     C_(t) = C_0 * e^(-k*t)
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ## 12. Copilot Debugging Challenge
#
# The following program contains a common numerical-integration error.
#
# Study it before asking Copilot.
#
# ```python
# C = 1.0
# k = 0.05
# dt = 1.0
#
# for step in range(10):
#     rate = -k * C
#     C_new = C + rate * dt
#     print(step + 1, C)
# ```
#
# ### Your task
#
# 1. Run the program.
# 2. Look carefully at the concentration values.
# 3. Decide whether the concentration is actually being updated.
# 4. Ask Copilot:
#
# > My Euler integration program calculates C_new but the next iteration does not appear to use the new concentration. Explain the likely logic problem without rewriting the complete program.
#
# 5. Correct the program yourself.

# %%
# Run the intentionally incorrect program here.
C = 1.0
k = 0.05
dt = 1.0

for step in range(10):
    rate = -k * C
    C_new = C + rate * dt
    print(step + 1, C)

# %% [markdown]
# ### Explain the error in your own words
#
# Write your explanation here before continuing.

# %% [markdown]
# ## 13. Testing Your Numerical Integration Program
#
# Test your program using different reaction conditions.
#
# | Test | C₀ (mol/L) | k (1/min) | dt (min) | Total Time (min) |
# |---|---:|---:|---:|---:|
# | 1 | 1.00 | 0.05 | 1.0 | 10 |
# | 2 | 2.00 | 0.02 | 1.0 | 20 |
# | 3 | 1.50 | 0.10 | 0.5 | 10 |
# | 4 | 1.00 | 0.05 | 0.1 | 10 |
# | 5 | 1.00 | 0.05 | 2.0 | 10 |
#
# For each case, record the final Euler concentration and, where possible, compare it with the analytical solution.

# %% [markdown]
# ## 14. Final Mini-Project – Batch Reaction Numerical Integrator
#
# Combine your work into one clean Python program.
#
# The final program should:
#
# 1. Accept `C₀`, `k`, `dt` and total simulation time from the user.
# 2. Validate the input values.
# 3. Numerically integrate `dC/dt = -kC` using the Euler method.
# 4. Use a loop to perform the integration steps.
# 5. Display time, concentration and conversion.
# 6. Calculate the analytical concentration using `math.exp()`.
# 7. Display the numerical error at the final time.
# 8. Clearly state that the Euler result is a numerical approximation.
#
# **Keep the program beginner-friendly. Do not use advanced libraries or techniques that have not been discussed in class.**

# %%
# FINAL PROGRAM
# Batch Reaction Numerical Integrator
# Write your clean final solution here.

import math

C0 = float(input("Enter initial concentration C0: "))
k = float(input("Enter rate constant k: "))
dt = float(input("Enter time step dt: "))
total_time = float(input("Enter total simulation time: "))

if C0 <= 0 or k <= 0 or dt <= 0 or total_time <= 0:
    print("Error: All values must be greater than zero.")
elif dt > total_time:
    print("Error: Time step cannot be greater than total simulation time.")
else:
    t = 0.0
    C = C0

    print("\nTime\tConcentration\tConversion (%)")

    while t < total_time:
        print(f"{t:.2f}\t{C:.6f}\t\t{((C0 - C) / C0) * 100:.2f}")

        step = min(dt, total_time - t)
        C = C + (-k * C) * step
        t = t + step

    conversion = ((C0 - C) / C0) * 100
    print(f"{t:.2f}\t{C:.6f}\t\t{conversion:.2f}")

    C_exact = C0 * math.exp(-k * total_time)
    error = abs(C - C_exact)

    print("\nFinal Results")
    print(f"Numerical concentration = {C:.4f}")
    print(f"Analytical concentration = {C_exact:.4f}")
    print(f"Numerical error = {error:.4f}")
# Out:
# Time	Concentration	Conversion (%)
# 0.00	1.000000		0.00
# 2.00	0.900000		10.00
# 4.00	0.810000		19.00
# 6.00	0.729000		27.10
# 8.00	0.656100		34.39
# 10.00	0.590490		40.95
# 12.00	0.531441		46.86
# 14.00	0.478297		52.17
# 16.00	0.430467		56.95
# 18.00	0.387420		61.26
# 20.00	0.348678		65.13
# 22.00	0.313811		68.62
# 24.00	0.282430		71.76
# 26.00	0.254187		74.58
# 28.00	0.228768		77.12
# 30.00	0.205891		79.41
#
# Final Results
# Numerical concentration = 0.2059
# Analytical concentration = 0.2231
# Numerical error = 0.0172

# %% [markdown]
# ## 15. Final Copilot Review
#
# After completing your final program, ask Copilot:
#
# > Review my Python Euler integration program for a first-order chemical reaction. Check whether the loop updates concentration correctly, whether the time step is used correctly, whether the stopping condition is correct, and whether the numerical result is compared properly with the analytical solution. Do not rewrite my program; identify possible issues and explain them.
#
# Make changes only after you understand the feedback.

# %% [markdown]
# ## 16. Reflection – What Did You Learn?
#
# Answer in your own words:
#
# 1. Why is a loop required for numerical integration?
# 2. What does `dC/dt = -kC` represent in this practical?
# 3. What does one Euler step calculate?
# 4. Why does the concentration from one step become the starting concentration for the next step?
# 5. What is the role of `dt` in numerical integration?
# 6. What did you observe when `dt` was changed?
# 7. Why can the Euler result differ from the analytical result?
# 8. What error did Copilot help you understand?
# 9. Which part of your program did you write or correct yourself after receiving a Copilot hint?
# 10. Can you explain your final program without opening Copilot?

# %% [markdown]
# ## 17. Submission Checklist
#
# - [ ] I completed all activities.
# - [ ] I used a `for` loop for numerical integration.
# - [ ] I used a `while` loop for condition-controlled integration.
# - [ ] I implemented the Euler method correctly.
# - [ ] I calculated conversion.
# - [ ] I investigated different time-step sizes.
# - [ ] I compared numerical and analytical results.
# - [ ] I calculated/observed numerical error.
# - [ ] I tested different reaction conditions.
# - [ ] I used Copilot for explanation and debugging rather than simply copying a complete solution.
# - [ ] I can explain my final program.
# - [ ] I saved the completed notebook in my GitHub repository.

# %% [markdown]
# ## 18. Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Basic variables and input | 1 |
# | Correct implementation of Euler step | 2 |
# | Correct use of loop for integration | 2 |
# | Conversion calculation | 1 |
# | Time-step investigation / numerical error | 1 |
# | Numerical vs analytical comparison | 1 |
# | Copilot usage and explanation | 1 |
# | Student's ability to explain/modify the program | 1 |
# | **Total** | **10** |
#
# **Faculty note:** During evaluation, change `dt` or `k` and ask the student to predict what should happen. Also ask why the concentration from the previous step is required in the next Euler calculation.
