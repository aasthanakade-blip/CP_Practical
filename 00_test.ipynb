# %%
print('aastha nakade')
# Out:
# aastha nakade

# %%
name = input('Enter your name: ')
print('Hello, ' + name + '!')
# Out:
# Hello, Aastha Nakade!

# %%
# Create a simple if elif else code to check marks and give
# grade A , B, C, D, F based on the marks entered by the user. 
marks = float(input('Enter your marks: '))

if 80 <= marks <= 100:
    grade = 'A'
elif 60 <= marks < 80:
    grade = 'B'
elif 40 <= marks < 60:
    grade = 'C'
elif 20<= marks < 40:
    grade = 'D'
else:
    grade = 'F'

print('Your grade is:', grade)
# Out:
# Your grade is: A
